# %% [markdown]
#  # Task 2 : Machine Learning  Supervised Classification Project

# %%
## import  numpy and pandas library
import pandas as pd
import numpy as np

# %%
## Load dataset
data = pd.read_csv('WineQT.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
###cheaking whate all are the information present in above data set
data.head(11)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             6.7             0.580         0.08             1.8      0.097
# 10            5.6             0.615         0.00             1.6      0.089
#
# ...

# %%
data.tail(11)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1132            6.2             0.460         0.29             2.1      0.074
# 1133            6.7             0.320         0.44             2.4      0.061
# 1134            7.5             0.310         0.41             2.4      0.065
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# # Exploratory Data Analysis
# ## EDA is an approach to analysing the data using visual techniques. It is used to discover trends, and patterns, or to check assumptions with the help of statistical summaries and graphical representations.  Now let's check the number of null values in the dataset columns wise.

# %%
### check weather our dataset cantain null value or not
data.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
### our dataset not cantaining any null values
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
### making ID Column first which is in last in our dataset
data= data.reindex(columns=[data.columns[-1]] + list(data.columns[:-1]))
data
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.4             0.700         0.00             1.9
# 1        1            7.8             0.880         0.00             2.6
# 2        2            7.8             0.760         0.04             2.3
# 3        3           11.2             0.280         0.56             1.9
# 4        4            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1138  1592            6.3             0.510         0.13             2.3
# 1139  1593            6.8             0.620         0.08             1.9
# 1140  1594            6.2             0.600         0.08             2.0
# 1141  1595            5.9             0.550         0.10             2.2
# 1142  1597            5.9             0.645         0.12             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
## the count plot to visualise the number data for each quality of wine.
import matplotlib.pyplot as plt         
plt.bar(data['quality'], data['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
print(data['quality'].value_counts())
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
### plot histogram to see the distribution of data
datas = data.drop(columns=['Id'])
datas.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
## scater plot
plt.scatter(datas['alcohol'], datas['quality'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.title('Scatter Plot: Alcohol vs Quality')
plt.show()

# %%
## plot heatmap to see correlation among all details present in data
import seaborn as sns
sns.set_style('darkgrid')
data_core = data.corr()
plt.figsize = (10,9)
sns.heatmap(data_core, annot=True, cmap='RdBu_r')
# Out:
# <Axes: >

# %%
## plot violinplot see ditribution of quality
sns.violinplot(data.quality,orient = 'h',color = 'b')
# Out:
# <Axes: xlabel='quality'>

# %%
data['quality_label'] = data['quality'].apply(lambda x: 'Good Quality' if x > 6 else 'Bad Quality')

# Show some examples of good quality and bad quality wines
good_quality_wines = data[data['quality_label'] == 'Good Quality'].head(5)
bad_quality_wines = data[data['quality_label'] == 'Bad Quality'].head(5)

print("Good Quality Wines:")
print(good_quality_wines)
print("\nBad Quality Wines:")
print(bad_quality_wines)
# Out:
# Good Quality Wines:
#      Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 7     7            7.3              0.65         0.00             1.2
# 8     8            7.8              0.58         0.02             2.0
# 12   16            8.5              0.28         0.56             1.8
# 27   37            8.1              0.38         0.28             2.1
# 89  128            8.0              0.59         0.16             1.8
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 7       0.065                 15.0                  21.0   0.9946  3.39
# 8       0.073                  9.0                  18.0   0.9968  3.36
# 12      0.092                 35.0                 103.0   0.9969  3.30
# 27      0.066                 13.0                  30.0   0.9968  3.23
# 89      0.065                  3.0                  16.0   0.9962  3.42
#
#     sulphates  alcohol  quality quality_label
# ...

# %%
x = data.drop(['quality','quality_label'], axis=1)
y= data['quality_label']

# %%
x
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.4             0.700         0.00             1.9
# 1        1            7.8             0.880         0.00             2.6
# 2        2            7.8             0.760         0.04             2.3
# 3        3           11.2             0.280         0.56             1.9
# 4        4            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1138  1592            6.3             0.510         0.13             2.3
# 1139  1593            6.8             0.620         0.08             1.9
# 1140  1594            6.2             0.600         0.08             2.0
# 1141  1595            5.9             0.550         0.10             2.2
# 1142  1597            5.9             0.645         0.12             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
y
# Out:
# 0       Bad Quality
# 1       Bad Quality
# 2       Bad Quality
# 3       Bad Quality
# 4       Bad Quality
#            ...
# 1138    Bad Quality
# 1139    Bad Quality
# 1140    Bad Quality
# 1141    Bad Quality
# 1142    Bad Quality
# Name: quality_label, Length: 1143, dtype: object

# %%
### now we have to split our dataset
## we have to first train our machin then test from dataset

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=1234)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (914, 12) (229, 12) (914,) (229,)

# %%
x_train
# Out:
#         Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 169    242            7.7             0.580         0.10            1.80
# 705   1006            9.1             0.290         0.33            2.05
# 449    633           10.1             0.935         0.22            3.40
# 39      56           10.2             0.420         0.57            3.40
# 1061  1486            6.8             0.680         0.21            2.10
# ...    ...            ...               ...          ...             ...
# 689    981            9.5             0.860         0.26            1.90
# 664    941            9.9             0.270         0.49            5.00
# 1077  1508            7.1             0.270         0.60            2.10
# 723   1027            6.4             0.795         0.00            2.20
# 815   1149           10.0             0.350         0.47            2.00
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
y_train
# Out:
# 169      Bad Quality
# 705     Good Quality
# 449      Bad Quality
# 39       Bad Quality
# 1061     Bad Quality
#             ...
# 689      Bad Quality
# 664     Good Quality
# 1077     Bad Quality
# 723      Bad Quality
# 815      Bad Quality
# Name: quality_label, Length: 914, dtype: object

# %%
x_test
# Out:
#        Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 221   307           10.3              0.41         0.42            2.40
# 308   437           11.1              0.45         0.73            3.20
# 680   964            8.5              0.47         0.27            1.90
# 920  1297            7.2              0.53         0.14            2.10
# 624   885            8.9              0.75         0.14            2.50
# ..    ...            ...               ...          ...             ...
# 248   353           13.5              0.53         0.79            4.80
# 835  1181            9.8              0.39         0.43            1.65
# 929  1309            7.0              0.62         0.10            1.40
# 104   152            7.5              0.60         0.03            1.80
# 183   259           10.0              0.31         0.47            2.60
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
y_test
# Out:
# 221     Bad Quality
# 308     Bad Quality
# 680     Bad Quality
# 920     Bad Quality
# 624     Bad Quality
#            ...
# 248     Bad Quality
# 835     Bad Quality
# 929     Bad Quality
# 104     Bad Quality
# 183    Good Quality
# Name: quality_label, Length: 229, dtype: object

# %% [markdown]
# ### Feature Scaling: Standardize or normalize your features to ensure they contribute equally.

# %%
## featur scaling:ther may be data with high scaling which differ our other data 
from sklearn.preprocessing import StandardScaler

# %%
sc_x  =  StandardScaler()
x_train_scaled = sc_x.fit_transform(x_train)
x_train_scaled
# Out:
# array([[-1.20818309, -0.34966973,  0.27999627, ..., -1.42580737,
#         -0.95387845, -0.59033166],
#        [ 0.43820031,  0.45276461, -1.33304027, ..., -0.31112466,
#          1.03132561,  1.17052366],
#        [-0.36559682,  1.02593199,  2.25457547, ...,  0.74163122,
#         -0.10307671,  0.79981727],
#        ...,
#        [ 1.51998627, -0.69357016, -1.44428416, ...,  0.43199714,
#          0.35068422,  0.1510811 ],
#        [ 0.48345431, -1.09478733,  1.47586818, ...,  1.11319212,
#         -0.7837181 ,  1.07784706],
#        [ 0.74635846,  0.96861525, -0.99930857, ..., -0.49690511,
#         -0.7837181 ,  1.44855344]])

# %%
x_test_scaled = sc_x.transform(x_test)
x_test_scaled
# Out:
# array([[-1.0681112 ,  1.14056547, -0.66557687, ..., -0.74461238,
#         -0.21651694, -0.86836145],
#        [-0.78796743,  1.59909938, -0.44308907, ..., -0.86846602,
#          0.01036352,  0.70714068],
#        [ 0.34769233,  0.10886418, -0.33184518, ..., -0.93039283,
#          1.08804572,  0.61446408],
#        ...,
#        [ 1.0911508 , -0.7508869 ,  0.50248407, ..., -0.18727103,
#         -0.27323706, -1.14639124],
#        [-1.40212878, -0.46430321,  0.39124017, ...,  0.24621669,
#         -0.67027787, -0.31230188],
#        [-1.1715489 ,  0.96861525, -1.22179637, ...,  0.3081435 ,
#          0.80444514,  0.05840451]])

# %% [markdown]
# # Train Model : Logistic Rregression

# %%
### Now train our model 
from sklearn.linear_model import LogisticRegression

# %%
##Fit a model to the training data.Using regression model as my task suggested
log = LogisticRegression(solver='lbfgs', max_iter=1000)
log.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
## Predict and Evaluate:
##Use the trained model to make predictions on the test data and evaluate performance
from sklearn.metrics import  accuracy_score , classification_report, confusion_matrix

import warnings
warnings.filterwarnings('ignore')


log_pred = log.predict(x_test)

y_test_str = y_test.astype(str)
log_pred_str = log_pred.astype(str)
## predict accuracy

accuracy = accuracy_score(y_test_str, log_pred_str)
print('Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test_str, log_pred_str))
print('Confusion Matrix:')
print(confusion_matrix(y_test_str, log_pred_str))
# Out:
# Accuracy: 0.8820960698689956
# Classification Report:
#               precision    recall  f1-score   support
#
#  Bad Quality       0.89      0.98      0.93       196
# Good Quality       0.75      0.27      0.40        33
#
#     accuracy                           0.88       229
#    macro avg       0.82      0.63      0.67       229
# weighted avg       0.87      0.88      0.86       229
#
# Confusion Matrix:
# [[193   3]
#  [ 24   9]]

# %% [markdown]
# # Plot  confusion matrics

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test, log_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier


# Train the model
DTC= DecisionTreeClassifier()
DTC.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import  accuracy_score , classification_report, confusion_matrix

DTC_pred = DTC.predict(x_test)

## predict accuracy
accuracy = accuracy_score(y_test, DTC_pred)
print('Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test, DTC_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, DTC_pred))
# Out:
# Accuracy: 0.8820960698689956
# Classification Report:
#               precision    recall  f1-score   support
#
#  Bad Quality       0.96      0.90      0.93       196
# Good Quality       0.57      0.76      0.65        33
#
#     accuracy                           0.88       229
#    macro avg       0.76      0.83      0.79       229
# weighted avg       0.90      0.88      0.89       229
#
# Confusion Matrix:
# [[177  19]
#  [  8  25]]

# %% [markdown]
# # PLOT Confusion matrix

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test, DTC_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier


# Train the model
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import  accuracy_score , classification_report, confusion_matrix

RFC_pred = RFC.predict(x_test)
## predict accuracy

accuracy = accuracy_score(y_test, RFC_pred)
print('Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test, RFC_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, RFC_pred))
# Out:
# Accuracy: 0.9039301310043668
# Classification Report:
#               precision    recall  f1-score   support
#
#  Bad Quality       0.92      0.97      0.95       196
# Good Quality       0.76      0.48      0.59        33
#
#     accuracy                           0.90       229
#    macro avg       0.84      0.73      0.77       229
# weighted avg       0.90      0.90      0.89       229
#
# Confusion Matrix:
# [[191   5]
#  [ 17  16]]

# %% [markdown]
# # PLOT Confusion matrix

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 6))
sns.heatmap(confusion_matrix(y_test, RFC_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
#  ### All three models—Logistic Regression, Decision Tree, and Random Forest—show accuracy between 85% to 95% range.This indicates they are performing better .In essence, while the current models provide good  accuracy,here are various strategies to further effectiveness.
